# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import hublib.rappture as rappture
from hublib import ureg, Q_

# %%
io = rappture.RapXML('hist_run.xml')

# %%
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.integer(points)</td><td>Number of points</td><td>Determines the number of data points in </td></tr></table>
# <h3>OUTPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>output.histogram(example)</td><td>Single dataset</td><td>This is an example of a single histogram</td></tr><tr bgcolor="#dddddd"><td>output.histogram(single)</td><td>Single histogram</td><td>This is an example of a single histogram</td></tr><tr bgcolor="#ffffff"><td>output.histogram(multi1)</td><td>Factor a=1</td><td>This is an example of a multiple histogr</td></tr><tr bgcolor="#dddddd"><td>output.histogram(multi2)</td><td>Factor a=2</td><td>This is an example of a multiple histogr</td></tr><tr bgcolor="#ffffff"><td>output.histogram(namevalue)</td><td>Name value histogram</td><td>This is an example of a name value histo</td></tr><tr bgcolor="#dddddd"><td>output.histogram(width)</td><td>Variable-Width histogram</td><td>This is an example of an <xhw> histogram</td></tr></table>

# %%
# %matplotlib notebook
io['output.histogram(example)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io['output.histogram(single)'].xml()
# Out:
# <histogram id="single">
#             <about>
#                 <label>Single histogram</label>
#                 <description>This is an example of a single histogram.</description>
#             </about>
#             <xaxis>
#                 <label>Time</label>
#                 <description>Time during the experiment.</description>
#                 <units>s</units>
#             </xaxis>
#             <yaxis>
#                 <label>Voltage v(11)</label>
#                 <description>Output from the amplifier.</description>
#                 <units>V</units>
#             </yaxis>
#             <component>
#                 <xy>1.0 0.27015115293406988
# 1.3333333333333333 0.10081610284413833
# 1.6666666666666665 -0.035896330505390789
# 2.0 -0.13871561218238079
# 2.333333333333333 -0.20722744192496284
# 2.6666666666666665 -0.24254360951264764
# 3.0 -0.24749812415011135
# 3.333333333333333 -0.22654015493332597
# 3.6666666666666665 -0.185418609200622
# 4.0 -0.13072872417272238
# 4.333333333333333 -0.069383121930475897
# 4.6666666666666661 -0.0080658326009261198
# 5.0 0.047277030910537705
# 5.333333333333333 0.091863708925132209
# 5.6666666666666661 0.12238444692028989
# 6.0 0.13716718380719514
# 6.333333333333333 0.13619220698572085
# 6.6666666666666661 0.12096100474577944
# 7.0 0.094237781792913075
# 7.333333333333333 0.059693116934053998
# 7.6666666666666661 0.021487096602719108
# 8.0 -0.016166670423179281
# 8.3333333333333321 -0.049414718481770113
# 8.6666666666666661 -0.075117505566488815
# 9.0 -0.0911130261884677
# 9.3333333333333321 -0.096369856721444283
# 9.6666666666666661 -0.091020683651613338
# 10.0 -0.076279229916041136</xy>
#             </component>
#         </histogram>

# %%
io['output.histogram(single)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io['output.histogram(multi1)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io['output.histogram(multi2)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io['output.histogram(namevalue)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io['output.histogram(width)'].xml()
# Out:
# <histogram id="width">
#             <about>
#                 <label>Variable-Width histogram</label>
#                 <description>This is an example of an &lt;xhw&gt; histogram.</description>
#             </about>
#             <xaxis>
#                 <label>Time</label>
#                 <description>Time during the experiment.</description>
#                 <units>s</units>
#             </xaxis>
#             <yaxis>
#                 <label>Voltage v(11)</label>
#                 <description>Output from the amplifier.</description>
#                 <units>V</units>
#             </yaxis>
#             <component>
#                 <xhw>"Bengal Tigers" 1.0 0.10000000000000001
# "Bears" 2.0 0.20000000000000001
# "Lions" 3.0 0.29999999999999999
# "Monkeys" 4.0 0.40000000000000002
# "Hawks" 5.0 0.5
# "Elephants" 6.0 0.59999999999999998
# "Foxes" 7.0 0.69999999999999996
# "Geckos" 8.0 0.80000000000000004
# "Zebras" 9.0 0.90000000000000002
# "Giraffes" 10.0 1.0</xhw>
#             </component>
#         </histogram>
