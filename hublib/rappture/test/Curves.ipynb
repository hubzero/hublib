# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import hublib.rappture as rappture
from hublib import ureg, Q_

# %%
io = rappture.RapXML('curve.xml')

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib

# %%
fig, axs = plt.subplots(1,2)
io['output.curve(single)'].plot(ax=axs[0]);
io['output.curve(single)'].plot(ax=axs[1]);
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
help(io['output.curve(single)'].plot)
# Out:
# Help on method plot in module hublib.rappture.curve:
#
# plot(single=False, ax=None) method of hublib.rappture.curve.Curve instance
#     Plots a curve, curve group, structure(molecule), or histogram.
#
#     :param single: Plot just a single curve instead of an entire group.

# %%
io['output.curve(single)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
curve = io['output.curve(single)']
curve.plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
out = io['output']
out['curve(single)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io['output.curve(single)'].plot
# Out:
# <bound method Curve.plot of <hublib.rappture.curve.Curve object at 0x7f66043a0dd8>>

# %%
io['output.curve(multi1)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.integer(points)</td><td>Number of points</td><td>Determines the number of data points in </td></tr></table>
# <h3>OUTPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>output.curve(single)</td><td>Single curve</td><td>This is an example of a single curve.</td></tr><tr bgcolor="#dddddd"><td>output.curve(multi1)</td><td>Factor a=1</td><td>This is an example of multiple curves on</td></tr><tr bgcolor="#ffffff"><td>output.curve(multi2)</td><td>Factor a=2</td><td>This is an example of multiple curves on</td></tr><tr bgcolor="#dddddd"><td>output.curve(multiA)</td><td>Factor a=1</td><td>This is an example of multiple curves on</td></tr><tr bgcolor="#ffffff"><td>output.curve(multiB)</td><td>Factor a=2</td><td>This is an example of multiple curves on</td></tr></table>
# <h3>CURVE GROUPS</h3><table><tr bgcolor="#cccccc"><th>Multiple Curve 2</th><tr bgcolor="#ffffff"><td>output.curve(multiA)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(multiB)</td></tr>
# </table>
# <table><tr bgcolor="#cccccc"><th>Multiple curves</th><tr bgcolor="#ffffff"><td>output.curve(multi1)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(multi2)</td></tr>
# </table>
