# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import hublib.rappture as rappture
from hublib import ureg, Q_

# %%
io = rappture.RapXML('s4run.xml')

# %%
io['input.phase(mode_option).image(S4_image)'].value

# %%
print(io)
# Out:
# input.phase(mode_option).choice(option)	"Simulation Option"
# input.phase(mode_option).image(S4_image)	""
# input.phase(parameter).group(input_deck).string(deck)	"Input deck"
# input.phase(parameter).group(input_deck).group(options).integer(ncpu)	"Number of processors"
# input.phase(parameter).group(input_deck).group(options).number(walltime)	"Walltime"
# input.phase(parameter).group(tab).group(materials).choice(matNum)	"Select the Number of Materials"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_7).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_7).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_7).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_8).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_8).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_8).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_9).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_9).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_9).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_10).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_10).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_10).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice1).number(x1)	"x1"
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice1).number(y1)	"y1"
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice2).number(x2)	"x2"
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice2).number(y2)	"y2"
# input.phase(parameter).group(tab).group(layers).choice(layerNum)	"Select Number of layers"
# input.phase(parameter).group(tab).group(layers).group(repL).boolean(if_repL)	"Do you need to repeat a range of layers?"
# input.phase(parameter).group(tab).group(layers).group(repL).integer(repL_S)	"repeated layers from:"
# input.phase(parameter).group(tab).group(layers).group(repL).integer(repL_E)	"to:"
# input.phase(parameter).group(tab).group(layers).group(repL).integer(repL_Num)	"Times the layers are copyed:"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL13).boolean(mvL1)	"Disable layer 1"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL13).boolean(mvL2)	"Disable layer 2"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL13).boolean(mvL3)	"Disable layer 3"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL46).boolean(mvL4)	"Disable layer 4"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL46).boolean(mvL5)	"Disable layer 5"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL46).boolean(mvL6)	"Disable layer 6"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL7)	"Disable layer 7"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL8)	"Disable layer 8"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL9)	"Disable layer 9"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL10)	"Disable layer 10"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).boolean(add_bot_layer)	"Copy this semi-infinite layer as bottom layer?"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(sim).integer(NumG)	"Max Fourier expansion orders"
# input.phase(parameter).group(tab).group(sim).group(wave).group(wave_angles).number(phi)	"phi"
# input.phase(parameter).group(tab).group(sim).group(wave).group(wave_angles).number(theta)	"theta"
# input.phase(parameter).group(tab).group(sim).group(wave).group(s_pol).number(s_amp)	"s_amp"
# input.phase(parameter).group(tab).group(sim).group(wave).group(s_pol).number(s_phase)	"s_phase"
# input.phase(parameter).group(tab).group(sim).group(wave).group(p_pol).number(p_amp)	"p_amp"
# input.phase(parameter).group(tab).group(sim).group(wave).group(p_pol).number(p_phase)	"p_phase"
# input.phase(parameter).group(tab).group(sim).group(freq).string(a)	"reduced units -> period:"
# input.phase(parameter).group(tab).group(sim).group(freq).group(lambda).number(lambda_min)	"minimum wavelength"
# input.phase(parameter).group(tab).group(sim).group(freq).group(lambda).number(lambda_max)	"maximum wavelength"
# input.phase(parameter).group(tab).group(sim).group(freq).group(lambda).number(lambda_step)	"real frequency increasing step"
# input.phase(parameter).group(tab).group(sim).boolean(smoothData)	"Smooth the resulted curves?"
# input.phase(parameter).group(tab).group(sim).integer(smoothrange)	"Smoothing range of moving average (nm):"
#
# output.log(output_log)	"Output Log"
# output.log(control_file)	"Control File"
# output.curve(2)	"	"
#
# CURVE GROUP: "Resulted Curve"
# 	output.curve(2)

# %%
io.inputs()
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.phase(mode_option).choice(option)</td><td>Simulation Option</td><td>input options</td></tr><tr bgcolor="#dddddd"><td>input.phase(mode_option).image(S4_image)</td><td></td><td>Structure Example
# Victor Liu and Shanhui</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(input_deck).string(deck)</td><td>Input deck</td><td>Input the control file for the program</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(input_deck).group(options).integer(ncpu)</td><td>Number of processors</td><td>Specify the number of processors for MPI</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(input_deck).group(options).number(walltime)</td><td>Walltime</td><td>Maximum interval for the run</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).choice(matNum)</td><td>Select the Number of Materials</td><td>select how many materials used in the si</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).choice(category)</td><td>Category</td><td>Select a category of materials</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).group(material-manual).number(r_eps)</td><td></td><td>real part of the relative permittivity o</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).group(material-manual).number(i_eps)</td><td></td><td>imaginary part of the relative permittiv</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).choice(category)</td><td>Category</td><td>Select a category of materials</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).group(material-manual).number(r_eps)</td><td></td><td>real part of the relative permittivity o</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).group(material-manual).number(i_eps)</td><td></td><td>imaginary part of the relative permittiv</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).choice(category)</td><td>Category</td><td>Select a category of materials</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).group(material-manual).number(r_eps)</td><td></td><td>real part of the relative permittivity o</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).group(material-manual).number(i_eps)</td><td></td><td>imaginary part of the relative permittiv</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).choice(category)</td><td>Category</td><td>Select a category of materials</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).group(material-manual).number(r_eps)</td><td></td><td>real part of the relative permittivity o</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).group(material-manual).number(i_eps)</td><td></td><td>imaginary part of the relative permittiv</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).choice(category)</td><td>Category</td><td>Select a category of materials</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).group(material-manual).number(r_eps)</td><td></td><td>real part of the relative permittivity o</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).group(material-manual).number(i_eps)</td><td></td><td>imaginary part of the relative permittiv</td></tr><tr bgcolor="#dddddd"><td>input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).choice(category)</td><td>Category</td><td>Select a category of materials</td></tr><tr bgcolor="#ffffff"><td>input.phase(parameter).group(tab).group(materials).group( ...

# %%
print(io.inputs())
# Out:
# input.phase(mode_option).choice(option)	"Simulation Option"
# input.phase(mode_option).image(S4_image)	""
# input.phase(parameter).group(input_deck).string(deck)	"Input deck"
# input.phase(parameter).group(input_deck).group(options).integer(ncpu)	"Number of processors"
# input.phase(parameter).group(input_deck).group(options).number(walltime)	"Walltime"
# input.phase(parameter).group(tab).group(materials).choice(matNum)	"Select the Number of Materials"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_1).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_2).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_3).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_4).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_5).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_6).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_7).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_7).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_7).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_8).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_8).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_8).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_9).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_9).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_9).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_10).choice(category)	"Category"
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_10).group(material-manual).number(r_eps)	""
# input.phase(parameter).group(tab).group(materials).group(mat110).group(mat_10).group(material-manual).number(i_eps)	""
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice1).number(x1)	"x1"
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice1).number(y1)	"y1"
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice2).number(x2)	"x2"
# input.phase(parameter).group(tab).group(layers).group(lattice).group(lattice2).number(y2)	"y2"
# input.phase(parameter).group(tab).group(layers).choice(layerNum)	"Select Number of layers"
# input.phase(parameter).group(tab).group(layers).group(repL).boolean(if_repL)	"Do you need to repeat a range of layers?"
# input.phase(parameter).group(tab).group(layers).group(repL).integer(repL_S)	"repeated layers from:"
# input.phase(parameter).group(tab).group(layers).group(repL).integer(repL_E)	"to:"
# input.phase(parameter).group(tab).group(layers).group(repL).integer(repL_Num)	"Times the layers are copyed:"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL13).boolean(mvL1)	"Disable layer 1"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL13).boolean(mvL2)	"Disable layer 2"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL13).boolean(mvL3)	"Disable layer 3"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL46).boolean(mvL4)	"Disable layer 4"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL46).boolean(mvL5)	"Disable layer 5"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL46).boolean(mvL6)	"Disable layer 6"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL7)	"Disable layer 7"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL8)	"Disable layer 8"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL9)	"Disable layer 9"
# input.phase(parameter).group(tab).group(layers).group(layer).group(mvL710).boolean(mvL10)	"Disable layer 10"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).boolean(add_bot_layer)	"Copy this semi-infinite layer as bottom layer?"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_0).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(pat_1).group(pat_1_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_1).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(pat_2).group(pat_2_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_2).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).number(radius)	"Radius (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).number(angle)	"Angle (in degree)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(pat_3).group(pat_3_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_3).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(pat_4).group(pat_4_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_4).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(pat_5).group(pat_5_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_5).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(pat_6).group(pat_6_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_6).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(pat_7).group(pat_7_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_7).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(pat_8).group(pat_8_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_8).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(pat_9).group(pat_9_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_9).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).number(thick)	"Thickness of the layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).integer(patNum)	"Select Number of patterns in this layer"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_1).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).choice(shape)	"Select the shape of the pattern"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).integer(mat_num)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(center).number(centerx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(center).number(centery)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).number(radius)	"Radius"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).number(angle)	"Angle"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(hw).number(hwx)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).group(hw).number(hwy)	""
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(pat_10).group(pat_10_2).string(vertices)	"Input the coordinates of the vertices of the polygon"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_10).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).integer(matNo)	"Material #"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).group(flux).boolean(get_flux)	"Get poynting flux"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).group(flux).number(flux_offset)	"Z-offset (nm)"
# input.phase(parameter).group(tab).group(layers).group(layer).group(layer_detail).group(layer_b).group(energy).boolean(get_energy)	"Get Electromagnetic energy"
# input.phase(parameter).group(tab).group(sim).integer(NumG)	"Max Fourier expansion orders"
# input.phase(parameter).group(tab).group(sim).group(wave).group(wave_angles).number(phi)	"phi"
# input.phase(parameter).group(tab).group(sim).group(wave).group(wave_angles).number(theta)	"theta"
# input.phase(parameter).group(tab).group(sim).group(wave).group(s_pol).number(s_amp)	"s_amp"
# input.phase(parameter).group(tab).group(sim).group(wave).group(s_pol).number(s_phase)	"s_phase"
# input.phase(parameter).group(tab).group(sim).group(wave).group(p_pol).number(p_amp)	"p_amp"
# input.phase(parameter).group(tab).group(sim).group(wave).group(p_pol).number(p_phase)	"p_phase"
# input.phase(parameter).group(tab).group(sim).group(freq).string(a)	"reduced units -> period:"
# input.phase(parameter).group(tab).group(sim).group(freq).group(lambda).number(lambda_min)	"minimum wavelength"
# input.phase(parameter).group(tab).group(sim).group(freq).group(lambda).number(lambda_max)	"maximum wavelength"
# input.phase(parameter).group(tab).group(sim).group(freq).group(lambda).number(lambda_step)	"real frequency increasing step"
# input.phase(parameter).group(tab).group(sim).boolean(smoothData)	"Smooth the resulted curves?"
# input.phase(parameter).group(tab).group(sim).integer(smoothrange)	"Smoothing range of moving average (nm):"

# %%
io.outputs()
# Out:
# <h3>OUTPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>output.log(output_log)</td><td>Output Log</td><td></td></tr><tr bgcolor="#dddddd"><td>output.log(control_file)</td><td>Control File</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(2)</td><td>	</td><td></td></tr></table>
# <h3>CURVE GROUPS</h3><table><tr bgcolor="#cccccc"><th>Resulted Curve</th><tr bgcolor="#ffffff"><td>output.curve(2)</td></tr>
# </table>

# %%
print(io['output.curve(2)'].xml())
# Out:
# <curve id="2">
#             <about>
#                 <group>Resulted Curve</group>
#                 <label>	</label>
#             </about>
#             <xaxis>
#                 <label>freq</label>
#             </xaxis>
#             <component>
#                 <xy>        0.25     0.908049
#        0.255     0.909058
#         0.26     0.910408
#        0.265     0.912114
#         0.27     0.914192
#        0.275     0.916657
#         0.28     0.919524
#        0.285     0.922804
#         0.29     0.926508
#        0.295     0.930645
#          0.3     0.935217
#        0.305      0.94022
#         0.31     0.945641
#        0.315     0.951456
#         0.32      0.95762
#        0.325     0.964066
#         0.33     0.970691
#        0.335     0.977346
#         0.34     0.983822
#        0.345     0.989819
#         0.35     0.994926
#        0.355     0.998576
#         0.36            1
#        0.365     0.998171
#         0.37     0.991742
#        0.375     0.978996
#         0.38     0.957834
#        0.385     0.925844
#         0.39     0.880529
#        0.395     0.819773
#          0.4     0.742558
#        0.405     0.649842
#         0.41     0.545256
#        0.415     0.435105
#         0.42     0.327366
#        0.425     0.229865
#         0.43     0.148446
#        0.435    0.0859671
#         0.44     0.042396
#        0.445    0.0156594
#         0.45   0.00267903
#        0.455  0.000197699
#         0.46   0.00527068
#        0.465     0.015472
#         0.47    0.0289204
#        0.475    0.0442165
#         0.48    0.0603493
#        0.485    0.0766039
#         0.49    0.0924815
#        0.495     0.107637
#          0.5     0.121832
#        0.505     0.134895
#         0.51     0.146702
#        0.515     0.157152
#         0.52     0.166154
#        0.525     0.173617
#         0.53     0.179442
#        0.535     0.183513
#         0.54     0.185693
#        0.545     0.185822
#         0.55      0.18371
#        0.555      0.17914
#         0.56     0.171869
#        0.565     0.161646
#         0.57     0.148236
#        0.575     0.131477
#         0.58     0.111374
#        0.585    0.0882637
#         0.59     0.063083
#        0.595    0.0377433
#          0.6    0.0155913
#        0.605   0.00175679
#         0.61   0.00295173
#        0.615    0.0260967
#         0.62     0.075559
#        0.625     0.150148
#         0.63      0.24228
#        0.635     0.340622
#         0.64     0.434465
#        0.645     0.516736
#         0.65     0.584471
#        0.655     0.637655
#         0.66     0.677788
#        0.665     0.706848
#         0.67     0.726727
#        0.675     0.739009
#         0.68     0.744923
#        0.685     0.745376
#         0.69     0.741018
#        0.695     0.732294
# </xy>
#             </component>
#         </curve>

# %%
# %matplotlib notebook
io['output.curve(2)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
