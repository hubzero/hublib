# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import hublib.rappture as rappture
from hublib import ureg, Q_

# %%
from IPython.display import display, Image

# %%
io = rappture.RapXML('circuits.xml')

# %%
io['input.image.current'].value

# %%
val = io['input.image'].value

# %%
val.width=500
val

# %%
Image(val.data, width=400)

# %%
ref = open('circuits.jpg', 'rb').read()
io['input.image.current'] = ref
val = io['input.image.current'].value
val

# %%
io = rappture.RapXML('image_test.xml')

# %%
io.inputs()
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.image()</td><td>Image</td><td>Input image that gets rotated.</td></tr><tr bgcolor="#dddddd"><td>input.number(angle)</td><td>Rotate</td><td>Rotate image by this amount in degrees.</td></tr></table>

# %%
v = io['input.image'].value
v

# %%
v.width=500
v

# %%
display(v, val)

# %%
io['output.image(outi)'].value
