# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import hublib.rappture as rappture
from hublib import ureg, Q_

# %%
from IPython.display import display, Image

# %%
#rappture.plot(io[], single=False, method='matplotlib')
#rappture.display(io[], **kwargs)
# why not regular display()?

# %%
io = rappture.RapXML('circuits.xml')

# %%
val = io['input.image.current'].value

# %%
val

# %%
val.width=500
val

# %%
Image(val.data, width=400)

# %%
ref = open('circuits.jpg', 'r').read()

# %%
ref == val.data
# Out:
# True

# %%
io = rappture.RapXML('image_test.xml')

# %%
io.list_inputs()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-e48cab558bcb> in <module>()
# ----> 1 io.list_inputs()
#
# AttributeError: 'RapXML' object has no attribute 'list_inputs'

# %%
print(io.list_inputs())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-c598befdb54a> in <module>()
# ----> 1 print(io.list_inputs())
#
# AttributeError: 'RapXML' object has no attribute 'list_inputs'

# %%
print(io.list_outputs())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-929d9d63bbce> in <module>()
# ----> 1 print(io.list_outputs())
#
# AttributeError: 'RapXML' object has no attribute 'list_outputs'

# %%
v = io['input.image'].value
v

# %%
v.width=500
v

# %%
display(v, val)

# %%
io['output.image(outi)'].value
